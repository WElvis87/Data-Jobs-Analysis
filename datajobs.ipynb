# %%
import pandas as pd

# %%
data = pd.read_csv("./data/data_jobs.csv")

# %%
data.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
data.shape
# Out:
# (785741, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
data.isnull()
# Out:
#         job_title_short  job_title  job_location  job_via  job_schedule_type  \
# 0                 False      False         False    False              False
# 1                 False      False         False    False              False
# 2                 False      False         False    False              False
# 3                 False      False         False    False              False
# 4                 False      False         False    False              False
# ...                 ...        ...           ...      ...                ...
# 785736            False      False         False    False              False
# 785737            False      False         False    False              False
# 785738            False      False         False    False              False
# 785739            False      False         False    False              False
# 785740            False      False         False    False              False
#
# ...

# %%
data.isnull().sum()
# Out:
# job_title_short               0
# job_title                     1
# job_location               1045
# job_via                       8
# job_schedule_type         12667
# job_work_from_home            0
# search_location               0
# job_posted_date               0
# job_no_degree_mention         0
# job_health_insurance          0
# job_country                  49
# salary_rate              752674
# salary_year_avg          763738
# salary_hour_avg          775079
# company_name                 18
# job_skills               117037
# job_type_skills          117037
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# job_title_short               0
# job_title                     1
# job_location               1045
# job_via                       8
# job_schedule_type         12667
# job_work_from_home            0
# search_location               0
# job_posted_date               0
# job_no_degree_mention         0
# job_health_insurance          0
# job_country                  49
# salary_rate              752674
# salary_year_avg          763738
# salary_hour_avg          775079
# company_name                 18
# job_skills               117037
# job_type_skills          117037
# dtype: int64

# %%
no_title = data[data["job_title"].isnull()]

# %%
no_title
# Out:
#        job_title_short job_title job_location  \
# 784492   Data Engineer       NaN          NaN
#
#                                    job_via job_schedule_type  \
# 784492  via Jobs In France - Mustakbil.com               NaN
#
#         job_work_from_home search_location      job_posted_date  \
# 784492               False     Saint Lucia  2023-12-14 07:32:05
#
#         job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 784492                  False                 False         NaN         NaN
#
#         salary_year_avg  salary_hour_avg company_name job_skills  \
# 784492              NaN              NaN          NaN        NaN
#
#        job_type_skills
# 784492             NaN

# %%
no_title["job_title"] = no_title["job_title_short"]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11160\3282938168.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_title["job_title"] = no_title["job_title_short"]

# %%
no_title
# Out:
#        job_title_short      job_title job_location  \
# 784492   Data Engineer  Data Engineer          NaN
#
#                                    job_via job_schedule_type  \
# 784492  via Jobs In France - Mustakbil.com               NaN
#
#         job_work_from_home search_location      job_posted_date  \
# 784492               False     Saint Lucia  2023-12-14 07:32:05
#
#         job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 784492                  False                 False         NaN         NaN
#
#         salary_year_avg  salary_hour_avg company_name job_skills  \
# 784492              NaN              NaN          NaN        NaN
#
#        job_type_skills
# 784492             NaN

# %%
data.update(no_title)

# %%
data.isnull().sum()
# Out:
# job_title_short               0
# job_title                     0
# job_location               1045
# job_via                       8
# job_schedule_type         12667
# job_work_from_home            0
# search_location               0
# job_posted_date               0
# job_no_degree_mention         0
# job_health_insurance          0
# job_country                  49
# salary_rate              752674
# salary_year_avg          763738
# salary_hour_avg          775079
# company_name                 18
# job_skills               117037
# job_type_skills          117037
# dtype: int64

# %%
data.dropna(subset=["job_location"], inplace=True)

# %%
data.isnull().sum()
# Out:
# job_title_short               0
# job_title                     0
# job_location                  0
# job_via                       8
# job_schedule_type         12659
# job_work_from_home            0
# search_location               0
# job_posted_date               0
# job_no_degree_mention         0
# job_health_insurance          0
# job_country                  48
# salary_rate              751985
# salary_year_avg          762973
# salary_hour_avg          774110
# company_name                 17
# job_skills               116921
# job_type_skills          116921
# dtype: int64

# %%
data.dropna(subset=["job_schedule_type"], inplace=True)

# %%
data.isnull().sum()
# Out:
# job_title_short               0
# job_title                     0
# job_location                  0
# job_via                       8
# job_schedule_type             0
# job_work_from_home            0
# search_location               0
# job_posted_date               0
# job_no_degree_mention         0
# job_health_insurance          0
# job_country                  48
# salary_rate              739468
# salary_year_avg          750330
# salary_hour_avg          761577
# company_name                 17
# job_skills               114839
# job_type_skills          114839
# dtype: int64

# %%
data.dropna(subset=["job_via", "job_country", "salary_year_avg", "job_skills"], inplace=True)

# %%
data.isnull().sum()
# Out:
# job_title_short              0
# job_title                    0
# job_location                 0
# job_via                      0
# job_schedule_type            0
# job_work_from_home           0
# search_location              0
# job_posted_date              0
# job_no_degree_mention        0
# job_health_insurance         0
# job_country                  0
# salary_rate                  0
# salary_year_avg              0
# salary_hour_avg          19908
# company_name                 0
# job_skills                   0
# job_type_skills              0
# dtype: int64

# %%
hour_avg = data[data["salary_hour_avg"].isnull()]

# %%
hour_avg
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19908 entries, 28 to 785692
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        19908 non-null  object
#  1   job_title              19908 non-null  object
#  2   job_location           19908 non-null  object
#  3   job_via                19908 non-null  object
#  4   job_schedule_type      19908 non-null  object
#  5   job_work_from_home     19908 non-null  bool
#  6   search_location        19908 non-null  object
#  7   job_posted_date        19908 non-null  object
#  8   job_no_degree_mention  19908 non-null  bool
#  9   job_health_insurance   19908 non-null  bool
#  10  job_country            19908 non-null  object
#  11  salary_rate            19908 non-null  object
#  12  salary_year_avg        19908 non-null  float64
#  13  salary_hour_avg        0 non-null      float64
# ...

# %%
hour_avg["salary_hour_avg"] = hour_avg["salary_year_avg"]/8760

# %%
hour_avg
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location  \
# ...

# %%
data.update(hour_avg)

# %%
data.isnull().sum()
# Out:
# job_title_short          0
# job_title                0
# job_location             0
# job_via                  0
# job_schedule_type        0
# job_work_from_home       0
# search_location          0
# job_posted_date          0
# job_no_degree_mention    0
# job_health_insurance     0
# job_country              0
# salary_rate              0
# salary_year_avg          0
# salary_hour_avg          0
# company_name             0
# job_skills               0
# job_type_skills          0
# dtype: int64

# %%
data.to_csv("./data/data_jobs.csv")

# %%
data
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location  \
# ...

# %%
data.shape
# Out:
# (19908, 17)

# %%
data.duplicated()
# Out:
# 28        False
# 77        False
# 92        False
# 100       False
# 109       False
#           ...
# 785563    False
# 785624    False
# 785648    False
# 785682    False
# 785692    False
# Length: 19908, dtype: bool

# %%
duplicates = data[data.duplicated()]

# %%
duplicates
# Out:
#        job_title_short     job_title job_location     job_via  \
# 689630    Data Analyst  Data Analyst     Anywhere  via Get.It
#
#        job_schedule_type  job_work_from_home          search_location  \
# 689630         Full-time                True  New York, United States
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 689630  2023-09-11 10:00:24                  False                  True
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 689630  United States        year          90000.0        10.273973
#
#                         company_name                              job_skills  \
# 689630  Get It Recruit - Real Estate  ['sql', 'bigquery', 'tableau', 'ssrs']
#
#                                           job_type_skills
# 689630  {'analyst_tools': ['tableau', 'ssrs'], 'cloud'...

# %%
data = data.drop_duplicates()

# %%
duplicates = data[data.duplicated()]

# %%
duplicates
# Out:
# Empty DataFrame
# Columns: [job_title_short, job_title, job_location, job_via, job_schedule_type, job_work_from_home, search_location, job_posted_date, job_no_degree_mention, job_health_insurance, job_country, salary_rate, salary_year_avg, salary_hour_avg, company_name, job_skills, job_type_skills]
# Index: []

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19907 entries, 28 to 785692
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        19907 non-null  object
#  1   job_title              19907 non-null  object
#  2   job_location           19907 non-null  object
#  3   job_via                19907 non-null  object
#  4   job_schedule_type      19907 non-null  object
#  5   job_work_from_home     19907 non-null  bool
#  6   search_location        19907 non-null  object
#  7   job_posted_date        19907 non-null  object
#  8   job_no_degree_mention  19907 non-null  bool
#  9   job_health_insurance   19907 non-null  bool
#  10  job_country            19907 non-null  object
#  11  salary_rate            19907 non-null  object
#  12  salary_year_avg        19907 non-null  float64
#  13  salary_hour_avg        19907 non-null  float64
# ...

# %%
data["job_posted_date"] = pd.to_datetime(data["job_posted_date"])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11160\2978980523.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["job_posted_date"] = pd.to_datetime(data["job_posted_date"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19907 entries, 28 to 785692
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        19907 non-null  object
#  1   job_title              19907 non-null  object
#  2   job_location           19907 non-null  object
#  3   job_via                19907 non-null  object
#  4   job_schedule_type      19907 non-null  object
#  5   job_work_from_home     19907 non-null  bool
#  6   search_location        19907 non-null  object
#  7   job_posted_date        19907 non-null  datetime64[ns]
#  8   job_no_degree_mention  19907 non-null  bool
#  9   job_health_insurance   19907 non-null  bool
#  10  job_country            19907 non-null  object
#  11  salary_rate            19907 non-null  object
#  12  salary_year_avg        19907 non-null  float64
#  13  salary_hour_avg        19907 non-null  float64
# ...

# %%
data.drop(columns="jobs_posted_date", inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11160\3678878751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns="jobs_posted_date", inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19907 entries, 28 to 785692
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        19907 non-null  object
#  1   job_title              19907 non-null  object
#  2   job_location           19907 non-null  object
#  3   job_via                19907 non-null  object
#  4   job_schedule_type      19907 non-null  object
#  5   job_work_from_home     19907 non-null  bool
#  6   search_location        19907 non-null  object
#  7   job_posted_date        19907 non-null  datetime64[ns]
#  8   job_no_degree_mention  19907 non-null  bool
#  9   job_health_insurance   19907 non-null  bool
#  10  job_country            19907 non-null  object
#  11  salary_rate            19907 non-null  object
#  12  salary_year_avg        19907 non-null  float64
#  13  salary_hour_avg        19907 non-null  float64
# ...

# %%
data["salary_hour_avg"] = data["salary_hour_avg"].astype(int)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11160\255464066.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["salary_hour_avg"] = data["salary_hour_avg"].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19907 entries, 28 to 785692
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        19907 non-null  object
#  1   job_title              19907 non-null  object
#  2   job_location           19907 non-null  object
#  3   job_via                19907 non-null  object
#  4   job_schedule_type      19907 non-null  object
#  5   job_work_from_home     19907 non-null  bool
#  6   search_location        19907 non-null  object
#  7   job_posted_date        19907 non-null  datetime64[ns]
#  8   job_no_degree_mention  19907 non-null  bool
#  9   job_health_insurance   19907 non-null  bool
#  10  job_country            19907 non-null  object
#  11  salary_rate            19907 non-null  object
#  12  salary_year_avg        19907 non-null  float64
#  13  salary_hour_avg        19907 non-null  int64
# ...

# %%
data["salary_year_avg"] = data["salary_year_avg"].astype(int)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11160\402403008.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["salary_year_avg"] = data["salary_year_avg"].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19907 entries, 28 to 785692
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        19907 non-null  object
#  1   job_title              19907 non-null  object
#  2   job_location           19907 non-null  object
#  3   job_via                19907 non-null  object
#  4   job_schedule_type      19907 non-null  object
#  5   job_work_from_home     19907 non-null  bool
#  6   search_location        19907 non-null  object
#  7   job_posted_date        19907 non-null  datetime64[ns]
#  8   job_no_degree_mention  19907 non-null  bool
#  9   job_health_insurance   19907 non-null  bool
#  10  job_country            19907 non-null  object
#  11  salary_rate            19907 non-null  object
#  12  salary_year_avg        19907 non-null  int64
#  13  salary_hour_avg        19907 non-null  int64
# ...

# %%
data.head()
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# ...
