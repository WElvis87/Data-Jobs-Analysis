# %%
import pandas as pd

# %%
data = pd.read_csv("./data/data_jobs.csv")

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 job_title_short  \
# 0             0          28  Data Scientist
# 1             1          77   Data Engineer
# 2             2          92   Data Engineer
# 3             3         100  Data Scientist
# 4             4         109    Data Analyst
#
#                                  job_title  \
# 0                      CRM Data Specialist
# 1                            Data Engineer
# 2  Remote - Data Engineer - Permanent - W2
# 3  Data Scientist, Risk Data Mining - USDS
# 4    Senior Supply Chain Analytics Analyst
#
#                               job_location          job_via job_schedule_type  \
# 0  San José Province, San José, Costa Rica  via Ai-Jobs.net         Full-time
# 1                            Arlington, VA     via LinkedIn         Full-time
# 2                                 Anywhere     via LinkedIn         Full-time
# 3                        Mountain View, CA     via LinkedIn         Full-time
# 4                                 Anywhere       via Get.It         Full-time
#
#    job_work_from_home            search_location      job_posted_date  \
# 0               False                 Costa Rica  2023-08-01 13:37:57
# 1               False                      Sudan  2023-06-26 14:22:54
# 2                True    Illinois, United States  2023-02-21 13:29:59
# 3               False  California, United States  2023-07-31 13:01:18
# 4                True    Illinois, United States  2023-10-12 13:02:19
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False     Costa Rica        year
# 1                  False                 False          Sudan        year
# 2                  False                  True  United States        year
# 3                  False                  True  United States        year
# 4                  False                  True  United States        year
#
#    salary_year_avg  salary_hour_avg                     company_name  \
# 0         109500.0        12.500000                         Netskope
# 1         140000.0        15.981735                       Intelletec
# 2         120000.0        13.698630                     Apex Systems
# 3         228222.0        26.052740                           TikTok
# 4          89000.0        10.159817  Get It Recruit - Transportation
#
#                                           job_skills  \
# 0                                  ['gdpr', 'excel']
# 1  ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 2                                  ['sql', 'python']
# 3                  ['sql', 'r', 'python', 'express']
# 4              ['python', 'r', 'alteryx', 'tableau']
#
#                                      job_type_skills
# 0  {'analyst_tools': ['excel'], 'libraries': ['gd...
# 1  {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 2                 {'programming': ['sql', 'python']}
# 3  {'programming': ['sql', 'r', 'python'], 'webfr...
# 4  {'analyst_tools': ['alteryx', 'tableau'], 'pro...

# %%
data.shape
# Out:
# (19908, 19)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19908 entries, 0 to 19907
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           19908 non-null  int64
#  1   Unnamed: 0             19908 non-null  int64
#  2   job_title_short        19908 non-null  object
#  3   job_title              19908 non-null  object
#  4   job_location           19908 non-null  object
#  5   job_via                19908 non-null  object
#  6   job_schedule_type      19908 non-null  object
#  7   job_work_from_home     19908 non-null  bool
#  8   search_location        19908 non-null  object
#  9   job_posted_date        19908 non-null  object
#  10  job_no_degree_mention  19908 non-null  bool
#  11  job_health_insurance   19908 non-null  bool
#  12  job_country            19908 non-null  object
#  13  salary_rate            19908 non-null  object
#  14  salary_year_avg        19908 non-null  float64
#  15  salary_hour_avg        19908 non-null  float64
#  16  company_name           19908 non-null  object
#  17  job_skills             19908 non-null  object
#  18  job_type_skills        19908 non-null  object
# dtypes: bool(3), float64(2), int64(2), object(12)
# memory usage: 2.5+ MB

# %%
data.isnull()
# Out:
#        Unnamed: 0.1  Unnamed: 0  job_title_short  job_title  job_location  \
# 0             False       False            False      False         False
# 1             False       False            False      False         False
# 2             False       False            False      False         False
# 3             False       False            False      False         False
# 4             False       False            False      False         False
# ...             ...         ...              ...        ...           ...
# 19903         False       False            False      False         False
# 19904         False       False            False      False         False
# 19905         False       False            False      False         False
# 19906         False       False            False      False         False
# 19907         False       False            False      False         False
#
#        job_via  job_schedule_type  job_work_from_home  search_location  \
# 0        False              False               False            False
# 1        False              False               False            False
# 2        False              False               False            False
# 3        False              False               False            False
# 4        False              False               False            False
# ...        ...                ...                 ...              ...
# 19903    False              False               False            False
# 19904    False              False               False            False
# 19905    False              False               False            False
# 19906    False              False               False            False
# 19907    False              False               False            False
#
#        job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0                False                  False                 False
# 1                False                  False                 False
# 2                False                  False                 False
# 3                False                  False                 False
# 4                False                  False                 False
# ...                ...                    ...                   ...
# 19903            False                  False                 False
# 19904            False                  False                 False
# 19905            False                  False                 False
# 19906            False                  False                 False
# 19907            False                  False                 False
#
#        job_country  salary_rate  salary_year_avg  salary_hour_avg  \
# 0            False        False            False            False
# 1            False        False            False            False
# 2            False        False            False            False
# 3            False        False            False            False
# 4            False        False            False            False
# ...            ...          ...              ...              ...
# 19903        False        False            False            False
# 19904        False        False            False            False
# 19905        False        False            False            False
# 19906        False        False            False            False
# 19907        False        False            False            False
#
#        company_name  job_skills  job_type_skills
# 0             False       False            False
# 1             False       False            False
# 2             False       False            False
# 3             False       False            False
# 4             False       False            False
# ...             ...         ...              ...
# 19903         False       False            False
# 19904         False       False            False
# 19905         False       False            False
# 19906         False       False            False
# 19907         False       False            False
#
# [19908 rows x 19 columns]

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.1             0
# Unnamed: 0               0
# job_title_short          0
# job_title                0
# job_location             0
# job_via                  0
# job_schedule_type        0
# job_work_from_home       0
# search_location          0
# job_posted_date          0
# job_no_degree_mention    0
# job_health_insurance     0
# job_country              0
# salary_rate              0
# salary_year_avg          0
# salary_hour_avg          0
# company_name             0
# job_skills               0
# job_type_skills          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19908 entries, 0 to 19907
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           19908 non-null  int64
#  1   Unnamed: 0             19908 non-null  int64
#  2   job_title_short        19908 non-null  object
#  3   job_title              19908 non-null  object
#  4   job_location           19908 non-null  object
#  5   job_via                19908 non-null  object
#  6   job_schedule_type      19908 non-null  object
#  7   job_work_from_home     19908 non-null  bool
#  8   search_location        19908 non-null  object
#  9   job_posted_date        19908 non-null  object
#  10  job_no_degree_mention  19908 non-null  bool
#  11  job_health_insurance   19908 non-null  bool
#  12  job_country            19908 non-null  object
#  13  salary_rate            19908 non-null  object
#  14  salary_year_avg        19908 non-null  float64
#  15  salary_hour_avg        19908 non-null  float64
#  16  company_name           19908 non-null  object
#  17  job_skills             19908 non-null  object
#  18  job_type_skills        19908 non-null  object
# dtypes: bool(3), float64(2), int64(2), object(12)
# memory usage: 2.5+ MB

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.1             0
# Unnamed: 0               0
# job_title_short          0
# job_title                0
# job_location             0
# job_via                  0
# job_schedule_type        0
# job_work_from_home       0
# search_location          0
# job_posted_date          0
# job_no_degree_mention    0
# job_health_insurance     0
# job_country              0
# salary_rate              0
# salary_year_avg          0
# salary_hour_avg          0
# company_name             0
# job_skills               0
# job_type_skills          0
# dtype: int64

# %%
no_title = data[data["job_title"].isnull()]

# %%
no_title
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, job_title_short, job_title, job_location, job_via, job_schedule_type, job_work_from_home, search_location, job_posted_date, job_no_degree_mention, job_health_insurance, job_country, salary_rate, salary_year_avg, salary_hour_avg, company_name, job_skills, job_type_skills]
# Index: []

# %%
no_title["job_title"] = no_title["job_title_short"]

# %%
no_title
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, job_title_short, job_title, job_location, job_via, job_schedule_type, job_work_from_home, search_location, job_posted_date, job_no_degree_mention, job_health_insurance, job_country, salary_rate, salary_year_avg, salary_hour_avg, company_name, job_skills, job_type_skills]
# Index: []

# %%
data.update(no_title)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.1             0
# Unnamed: 0               0
# job_title_short          0
# job_title                0
# job_location             0
# job_via                  0
# job_schedule_type        0
# job_work_from_home       0
# search_location          0
# job_posted_date          0
# job_no_degree_mention    0
# job_health_insurance     0
# job_country              0
# salary_rate              0
# salary_year_avg          0
# salary_hour_avg          0
# company_name             0
# job_skills               0
# job_type_skills          0
# dtype: int64

# %%
data.dropna(subset=["job_location"], inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.1             0
# Unnamed: 0               0
# job_title_short          0
# job_title                0
# job_location             0
# job_via                  0
# job_schedule_type        0
# job_work_from_home       0
# search_location          0
# job_posted_date          0
# job_no_degree_mention    0
# job_health_insurance     0
# job_country              0
# salary_rate              0
# salary_year_avg          0
# salary_hour_avg          0
# company_name             0
# job_skills               0
# job_type_skills          0
# dtype: int64

# %%
data.dropna(subset=["job_schedule_type"], inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.1             0
# Unnamed: 0               0
# job_title_short          0
# job_title                0
# job_location             0
# job_via                  0
# job_schedule_type        0
# job_work_from_home       0
# search_location          0
# job_posted_date          0
# job_no_degree_mention    0
# job_health_insurance     0
# job_country              0
# salary_rate              0
# salary_year_avg          0
# salary_hour_avg          0
# company_name             0
# job_skills               0
# job_type_skills          0
# dtype: int64

# %%
data.dropna(subset=["job_via", "job_country", "salary_year_avg", "job_skills"], inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.1             0
# Unnamed: 0               0
# job_title_short          0
# job_title                0
# job_location             0
# job_via                  0
# job_schedule_type        0
# job_work_from_home       0
# search_location          0
# job_posted_date          0
# job_no_degree_mention    0
# job_health_insurance     0
# job_country              0
# salary_rate              0
# salary_year_avg          0
# salary_hour_avg          0
# company_name             0
# job_skills               0
# job_type_skills          0
# dtype: int64

# %%
hour_avg = data[data["salary_hour_avg"].isnull()]

# %%
hour_avg
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, job_title_short, job_title, job_location, job_via, job_schedule_type, job_work_from_home, search_location, job_posted_date, job_no_degree_mention, job_health_insurance, job_country, salary_rate, salary_year_avg, salary_hour_avg, company_name, job_skills, job_type_skills]
# Index: []

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19908 entries, 0 to 19907
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           19908 non-null  int64
#  1   Unnamed: 0             19908 non-null  int64
#  2   job_title_short        19908 non-null  object
#  3   job_title              19908 non-null  object
#  4   job_location           19908 non-null  object
#  5   job_via                19908 non-null  object
#  6   job_schedule_type      19908 non-null  object
#  7   job_work_from_home     19908 non-null  bool
#  8   search_location        19908 non-null  object
#  9   job_posted_date        19908 non-null  object
#  10  job_no_degree_mention  19908 non-null  bool
#  11  job_health_insurance   19908 non-null  bool
#  12  job_country            19908 non-null  object
#  13  salary_rate            19908 non-null  object
#  14  salary_year_avg        19908 non-null  float64
#  15  salary_hour_avg        19908 non-null  float64
#  16  company_name           19908 non-null  object
#  17  job_skills             19908 non-null  object
#  18  job_type_skills        19908 non-null  object
# dtypes: bool(3), float64(2), int64(2), object(12)
# memory usage: 2.5+ MB

# %%
hour_avg["salary_hour_avg"] = hour_avg["salary_year_avg"]/8760

# %%
hour_avg
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, job_title_short, job_title, job_location, job_via, job_schedule_type, job_work_from_home, search_location, job_posted_date, job_no_degree_mention, job_health_insurance, job_country, salary_rate, salary_year_avg, salary_hour_avg, company_name, job_skills, job_type_skills]
# Index: []

# %%
data.update(hour_avg)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.1             0
# Unnamed: 0               0
# job_title_short          0
# job_title                0
# job_location             0
# job_via                  0
# job_schedule_type        0
# job_work_from_home       0
# search_location          0
# job_posted_date          0
# job_no_degree_mention    0
# job_health_insurance     0
# job_country              0
# salary_rate              0
# salary_year_avg          0
# salary_hour_avg          0
# company_name             0
# job_skills               0
# job_type_skills          0
# dtype: int64

# %%
data.to_csv("./data/data_jobs.csv")

# %%
data
# Out:
#        Unnamed: 0.1  Unnamed: 0 job_title_short  \
# 0                 0          28  Data Scientist
# 1                 1          77   Data Engineer
# 2                 2          92   Data Engineer
# 3                 3         100  Data Scientist
# 4                 4         109    Data Analyst
# ...             ...         ...             ...
# 19903         19903      785563  Data Scientist
# 19904         19904      785624   Data Engineer
# 19905         19905      785648  Data Scientist
# 19906         19906      785682  Data Scientist
# 19907         19907      785692  Data Scientist
#
#                                                job_title  \
# 0                                    CRM Data Specialist
# 1                                          Data Engineer
# 2                Remote - Data Engineer - Permanent - W2
# 3                Data Scientist, Risk Data Mining - USDS
# 4                  Senior Supply Chain Analytics Analyst
# ...                                                  ...
# 19903  Data Scientist I/II (Model Risk Management & M...
# 19904                   Data Analytics Engineer (Hybrid)
# 19905  Director Data Scientist - Commercial Platforms...
# 19906  Data Scientist für datengetriebene Entwicklung...
# 19907               Data Scientist- Hybrid Work Location
#
#                                   job_location  \
# 0      San José Province, San José, Costa Rica
# 1                                Arlington, VA
# 2                                     Anywhere
# 3                            Mountain View, CA
# 4                                     Anywhere
# ...                                        ...
# 19903                            Pensacola, FL
# 19904                          Mt Prospect, IL
# 19905                        Pleasant Hill, CA
# 19906                      Reutlingen, Germany
# 19907                               Dayton, OH
#
#                                          job_via job_schedule_type  \
# 0                                via Ai-Jobs.net         Full-time
# 1                                   via LinkedIn         Full-time
# 2                                   via LinkedIn         Full-time
# 3                                   via LinkedIn         Full-time
# 4                                     via Get.It         Full-time
# ...                                          ...               ...
# 19903  via Navy Federal Credit Union - Talentify         Full-time
# 19904                            via Ai-Jobs.net         Full-time
# 19905                            via Ai-Jobs.net         Full-time
# 19906                            via Ai-Jobs.net         Full-time
# 19907                            via Ai-Jobs.net         Full-time
#
#        job_work_from_home            search_location      job_posted_date  \
# 0                   False                 Costa Rica  2023-08-01 13:37:57
# 1                   False                      Sudan  2023-06-26 14:22:54
# 2                    True    Illinois, United States  2023-02-21 13:29:59
# 3                   False  California, United States  2023-07-31 13:01:18
# 4                    True    Illinois, United States  2023-10-12 13:02:19
# ...                   ...                        ...                  ...
# 19903               False     Florida, United States  2023-01-11 06:22:10
# 19904               False    Illinois, United States  2023-08-31 06:02:16
# 19905               False  California, United States  2023-04-12 06:02:51
# 19906               False                    Germany  2023-03-04 06:16:08
# 19907               False    Illinois, United States  2023-04-21 06:02:31
#
#        job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                      False                 False     Costa Rica        year
# 1                      False                 False          Sudan        year
# 2                      False                  True  United States        year
# 3                      False                  True  United States        year
# 4                      False                  True  United States        year
# ...                      ...                   ...            ...         ...
# 19903                  False                 False  United States        year
# 19904                  False                  True  United States        year
# 19905                  False                  True  United States        year
# 19906                  False                 False        Germany        year
# 19907                  False                  True  United States        year
#
#        salary_year_avg  salary_hour_avg                     company_name  \
# 0             109500.0        12.500000                         Netskope
# 1             140000.0        15.981735                       Intelletec
# 2             120000.0        13.698630                     Apex Systems
# 3             228222.0        26.052740                           TikTok
# 4              89000.0        10.159817  Get It Recruit - Transportation
# ...                ...              ...                              ...
# 19903         136400.0        15.570776        Navy Federal Credit Union
# 19904         139216.0        15.892237                      Bosch Group
# 19905         221875.0        25.328196                           84.51°
# 19906         157500.0        17.979452                      Bosch Group
# 19907         157500.0        17.979452                           Tenet3
#
#                                               job_skills  \
# 0                                      ['gdpr', 'excel']
# 1      ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 2                                      ['sql', 'python']
# 3                      ['sql', 'r', 'python', 'express']
# 4                  ['python', 'r', 'alteryx', 'tableau']
# ...                                                  ...
# 19903  ['r', 'python', 'matplotlib', 'ggplot2', 'spar...
# 19904  ['go', 'python', 'r', 'sql', 'oracle', 'window...
# 19905          ['python', 'azure', 'snowflake', 'spark']
# 19906  ['python', 'hadoop', 'spark', 'airflow', 'kube...
# 19907                          ['python', 'matlab', 'r']
#
#                                          job_type_skills
# 0      {'analyst_tools': ['excel'], 'libraries': ['gd...
# 1      {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 2                     {'programming': ['sql', 'python']}
# 3      {'programming': ['sql', 'r', 'python'], 'webfr...
# 4      {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# ...                                                  ...
# 19903  {'analyst_tools': ['word', 'power bi', 'tablea...
# 19904  {'analyst_tools': ['alteryx', 'power bi', 'tab...
# 19905  {'cloud': ['azure', 'snowflake'], 'libraries':...
# 19906  {'libraries': ['hadoop', 'spark', 'airflow'], ...
# 19907         {'programming': ['python', 'matlab', 'r']}
#
# [19908 rows x 19 columns]

# %%
data.shape
# Out:
# (19908, 19)

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19903    False
# 19904    False
# 19905    False
# 19906    False
# 19907    False
# Length: 19908, dtype: bool

# %%
duplicates = data[data.duplicated()]

# %%
duplicates
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, job_title_short, job_title, job_location, job_via, job_schedule_type, job_work_from_home, search_location, job_posted_date, job_no_degree_mention, job_health_insurance, job_country, salary_rate, salary_year_avg, salary_hour_avg, company_name, job_skills, job_type_skills]
# Index: []

# %%
data = data.drop_duplicates()

# %%
duplicates = data[data.duplicated()]

# %%
duplicates
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, job_title_short, job_title, job_location, job_via, job_schedule_type, job_work_from_home, search_location, job_posted_date, job_no_degree_mention, job_health_insurance, job_country, salary_rate, salary_year_avg, salary_hour_avg, company_name, job_skills, job_type_skills]
# Index: []

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19908 entries, 0 to 19907
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           19908 non-null  int64
#  1   Unnamed: 0             19908 non-null  int64
#  2   job_title_short        19908 non-null  object
#  3   job_title              19908 non-null  object
#  4   job_location           19908 non-null  object
#  5   job_via                19908 non-null  object
#  6   job_schedule_type      19908 non-null  object
#  7   job_work_from_home     19908 non-null  bool
#  8   search_location        19908 non-null  object
#  9   job_posted_date        19908 non-null  object
#  10  job_no_degree_mention  19908 non-null  bool
#  11  job_health_insurance   19908 non-null  bool
#  12  job_country            19908 non-null  object
#  13  salary_rate            19908 non-null  object
#  14  salary_year_avg        19908 non-null  float64
#  15  salary_hour_avg        19908 non-null  float64
#  16  company_name           19908 non-null  object
#  17  job_skills             19908 non-null  object
#  18  job_type_skills        19908 non-null  object
# dtypes: bool(3), float64(2), int64(2), object(12)
# memory usage: 2.5+ MB

# %%
data["job_posted_date"] = pd.to_datetime(data["job_posted_date"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19908 entries, 0 to 19907
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           19908 non-null  int64
#  1   Unnamed: 0             19908 non-null  int64
#  2   job_title_short        19908 non-null  object
#  3   job_title              19908 non-null  object
#  4   job_location           19908 non-null  object
#  5   job_via                19908 non-null  object
#  6   job_schedule_type      19908 non-null  object
#  7   job_work_from_home     19908 non-null  bool
#  8   search_location        19908 non-null  object
#  9   job_posted_date        19908 non-null  datetime64[ns]
#  10  job_no_degree_mention  19908 non-null  bool
#  11  job_health_insurance   19908 non-null  bool
#  12  job_country            19908 non-null  object
#  13  salary_rate            19908 non-null  object
#  14  salary_year_avg        19908 non-null  float64
#  15  salary_hour_avg        19908 non-null  float64
#  16  company_name           19908 non-null  object
#  17  job_skills             19908 non-null  object
#  18  job_type_skills        19908 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), int64(2), object(11)
# memory usage: 2.5+ MB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19908 entries, 0 to 19907
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           19908 non-null  int64
#  1   Unnamed: 0             19908 non-null  int64
#  2   job_title_short        19908 non-null  object
#  3   job_title              19908 non-null  object
#  4   job_location           19908 non-null  object
#  5   job_via                19908 non-null  object
#  6   job_schedule_type      19908 non-null  object
#  7   job_work_from_home     19908 non-null  bool
#  8   search_location        19908 non-null  object
#  9   job_posted_date        19908 non-null  datetime64[ns]
#  10  job_no_degree_mention  19908 non-null  bool
#  11  job_health_insurance   19908 non-null  bool
#  12  job_country            19908 non-null  object
#  13  salary_rate            19908 non-null  object
#  14  salary_year_avg        19908 non-null  float64
#  15  salary_hour_avg        19908 non-null  float64
#  16  company_name           19908 non-null  object
#  17  job_skills             19908 non-null  object
#  18  job_type_skills        19908 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), int64(2), object(11)
# memory usage: 2.5+ MB

# %%
data["salary_hour_avg"] = data["salary_hour_avg"].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19908 entries, 0 to 19907
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           19908 non-null  int64
#  1   Unnamed: 0             19908 non-null  int64
#  2   job_title_short        19908 non-null  object
#  3   job_title              19908 non-null  object
#  4   job_location           19908 non-null  object
#  5   job_via                19908 non-null  object
#  6   job_schedule_type      19908 non-null  object
#  7   job_work_from_home     19908 non-null  bool
#  8   search_location        19908 non-null  object
#  9   job_posted_date        19908 non-null  datetime64[ns]
#  10  job_no_degree_mention  19908 non-null  bool
#  11  job_health_insurance   19908 non-null  bool
#  12  job_country            19908 non-null  object
#  13  salary_rate            19908 non-null  object
#  14  salary_year_avg        19908 non-null  float64
#  15  salary_hour_avg        19908 non-null  int64
#  16  company_name           19908 non-null  object
#  17  job_skills             19908 non-null  object
#  18  job_type_skills        19908 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(1), int64(3), object(11)
# memory usage: 2.5+ MB

# %%
data["salary_year_avg"] = data["salary_year_avg"].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19908 entries, 0 to 19907
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           19908 non-null  int64
#  1   Unnamed: 0             19908 non-null  int64
#  2   job_title_short        19908 non-null  object
#  3   job_title              19908 non-null  object
#  4   job_location           19908 non-null  object
#  5   job_via                19908 non-null  object
#  6   job_schedule_type      19908 non-null  object
#  7   job_work_from_home     19908 non-null  bool
#  8   search_location        19908 non-null  object
#  9   job_posted_date        19908 non-null  datetime64[ns]
#  10  job_no_degree_mention  19908 non-null  bool
#  11  job_health_insurance   19908 non-null  bool
#  12  job_country            19908 non-null  object
#  13  salary_rate            19908 non-null  object
#  14  salary_year_avg        19908 non-null  int64
#  15  salary_hour_avg        19908 non-null  int64
#  16  company_name           19908 non-null  object
#  17  job_skills             19908 non-null  object
#  18  job_type_skills        19908 non-null  object
# dtypes: bool(3), datetime64[ns](1), int64(4), object(11)
# memory usage: 2.5+ MB

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 job_title_short  \
# 0             0          28  Data Scientist
# 1             1          77   Data Engineer
# 2             2          92   Data Engineer
# 3             3         100  Data Scientist
# 4             4         109    Data Analyst
#
#                                  job_title  \
# 0                      CRM Data Specialist
# 1                            Data Engineer
# 2  Remote - Data Engineer - Permanent - W2
# 3  Data Scientist, Risk Data Mining - USDS
# 4    Senior Supply Chain Analytics Analyst
#
#                               job_location          job_via job_schedule_type  \
# 0  San José Province, San José, Costa Rica  via Ai-Jobs.net         Full-time
# 1                            Arlington, VA     via LinkedIn         Full-time
# 2                                 Anywhere     via LinkedIn         Full-time
# 3                        Mountain View, CA     via LinkedIn         Full-time
# 4                                 Anywhere       via Get.It         Full-time
#
#    job_work_from_home            search_location     job_posted_date  \
# 0               False                 Costa Rica 2023-08-01 13:37:57
# 1               False                      Sudan 2023-06-26 14:22:54
# 2                True    Illinois, United States 2023-02-21 13:29:59
# 3               False  California, United States 2023-07-31 13:01:18
# 4                True    Illinois, United States 2023-10-12 13:02:19
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False     Costa Rica        year
# 1                  False                 False          Sudan        year
# 2                  False                  True  United States        year
# 3                  False                  True  United States        year
# 4                  False                  True  United States        year
#
#    salary_year_avg  salary_hour_avg                     company_name  \
# 0           109500               12                         Netskope
# 1           140000               15                       Intelletec
# 2           120000               13                     Apex Systems
# 3           228222               26                           TikTok
# 4            89000               10  Get It Recruit - Transportation
#
#                                           job_skills  \
# 0                                  ['gdpr', 'excel']
# 1  ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 2                                  ['sql', 'python']
# 3                  ['sql', 'r', 'python', 'express']
# 4              ['python', 'r', 'alteryx', 'tableau']
#
#                                      job_type_skills
# 0  {'analyst_tools': ['excel'], 'libraries': ['gd...
# 1  {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 2                 {'programming': ['sql', 'python']}
# 3  {'programming': ['sql', 'r', 'python'], 'webfr...
# 4  {'analyst_tools': ['alteryx', 'tableau'], 'pro...

# %%
data.to_csv("./data/data_jobs.csv")

# %%
data
# Out:
#        Unnamed: 0.1  Unnamed: 0 job_title_short  \
# 0                 0          28  Data Scientist
# 1                 1          77   Data Engineer
# 2                 2          92   Data Engineer
# 3                 3         100  Data Scientist
# 4                 4         109    Data Analyst
# ...             ...         ...             ...
# 19903         19903      785563  Data Scientist
# 19904         19904      785624   Data Engineer
# 19905         19905      785648  Data Scientist
# 19906         19906      785682  Data Scientist
# 19907         19907      785692  Data Scientist
#
#                                                job_title  \
# 0                                    CRM Data Specialist
# 1                                          Data Engineer
# 2                Remote - Data Engineer - Permanent - W2
# 3                Data Scientist, Risk Data Mining - USDS
# 4                  Senior Supply Chain Analytics Analyst
# ...                                                  ...
# 19903  Data Scientist I/II (Model Risk Management & M...
# 19904                   Data Analytics Engineer (Hybrid)
# 19905  Director Data Scientist - Commercial Platforms...
# 19906  Data Scientist für datengetriebene Entwicklung...
# 19907               Data Scientist- Hybrid Work Location
#
#                                   job_location  \
# 0      San José Province, San José, Costa Rica
# 1                                Arlington, VA
# 2                                     Anywhere
# 3                            Mountain View, CA
# 4                                     Anywhere
# ...                                        ...
# 19903                            Pensacola, FL
# 19904                          Mt Prospect, IL
# 19905                        Pleasant Hill, CA
# 19906                      Reutlingen, Germany
# 19907                               Dayton, OH
#
#                                          job_via job_schedule_type  \
# 0                                via Ai-Jobs.net         Full-time
# 1                                   via LinkedIn         Full-time
# 2                                   via LinkedIn         Full-time
# 3                                   via LinkedIn         Full-time
# 4                                     via Get.It         Full-time
# ...                                          ...               ...
# 19903  via Navy Federal Credit Union - Talentify         Full-time
# 19904                            via Ai-Jobs.net         Full-time
# 19905                            via Ai-Jobs.net         Full-time
# 19906                            via Ai-Jobs.net         Full-time
# 19907                            via Ai-Jobs.net         Full-time
#
#        job_work_from_home            search_location     job_posted_date  \
# 0                   False                 Costa Rica 2023-08-01 13:37:57
# 1                   False                      Sudan 2023-06-26 14:22:54
# 2                    True    Illinois, United States 2023-02-21 13:29:59
# 3                   False  California, United States 2023-07-31 13:01:18
# 4                    True    Illinois, United States 2023-10-12 13:02:19
# ...                   ...                        ...                 ...
# 19903               False     Florida, United States 2023-01-11 06:22:10
# 19904               False    Illinois, United States 2023-08-31 06:02:16
# 19905               False  California, United States 2023-04-12 06:02:51
# 19906               False                    Germany 2023-03-04 06:16:08
# 19907               False    Illinois, United States 2023-04-21 06:02:31
#
#        job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                      False                 False     Costa Rica        year
# 1                      False                 False          Sudan        year
# 2                      False                  True  United States        year
# 3                      False                  True  United States        year
# 4                      False                  True  United States        year
# ...                      ...                   ...            ...         ...
# 19903                  False                 False  United States        year
# 19904                  False                  True  United States        year
# 19905                  False                  True  United States        year
# 19906                  False                 False        Germany        year
# 19907                  False                  True  United States        year
#
#        salary_year_avg  salary_hour_avg                     company_name  \
# 0               109500               12                         Netskope
# 1               140000               15                       Intelletec
# 2               120000               13                     Apex Systems
# 3               228222               26                           TikTok
# 4                89000               10  Get It Recruit - Transportation
# ...                ...              ...                              ...
# 19903           136400               15        Navy Federal Credit Union
# 19904           139216               15                      Bosch Group
# 19905           221875               25                           84.51°
# 19906           157500               17                      Bosch Group
# 19907           157500               17                           Tenet3
#
#                                               job_skills  \
# 0                                      ['gdpr', 'excel']
# 1      ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 2                                      ['sql', 'python']
# 3                      ['sql', 'r', 'python', 'express']
# 4                  ['python', 'r', 'alteryx', 'tableau']
# ...                                                  ...
# 19903  ['r', 'python', 'matplotlib', 'ggplot2', 'spar...
# 19904  ['go', 'python', 'r', 'sql', 'oracle', 'window...
# 19905          ['python', 'azure', 'snowflake', 'spark']
# 19906  ['python', 'hadoop', 'spark', 'airflow', 'kube...
# 19907                          ['python', 'matlab', 'r']
#
#                                          job_type_skills
# 0      {'analyst_tools': ['excel'], 'libraries': ['gd...
# 1      {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 2                     {'programming': ['sql', 'python']}
# 3      {'programming': ['sql', 'r', 'python'], 'webfr...
# 4      {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# ...                                                  ...
# 19903  {'analyst_tools': ['word', 'power bi', 'tablea...
# 19904  {'analyst_tools': ['alteryx', 'power bi', 'tab...
# 19905  {'cloud': ['azure', 'snowflake'], 'libraries':...
# 19906  {'libraries': ['hadoop', 'spark', 'airflow'], ...
# 19907         {'programming': ['python', 'matlab', 'r']}
#
# [19908 rows x 19 columns]
